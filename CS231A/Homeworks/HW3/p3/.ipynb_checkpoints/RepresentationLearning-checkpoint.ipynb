# %% [markdown]
# # CS231a PSET 3 Problem 3: Representation Learning with Self-Supervised Learning

# %% [markdown]
# # Problem Layout
#
# In this notebook, we will be using the [MNIST dataset](https://en.wikipedia.org/wiki/MNIST_database) to show case how self-supervised representation learning can be utilized for more efficient training in downstream tasks. We will do the following things:
#
# 1. Train a classifier from scratch on the MNIST dataset and observe how fast and well it learns.
#
# 2. Train useful representations via predicting digit rotations, rather than classifying digits.
#
# 3. Transfer our rotation pretraining features to solve the classification task with much less data than in step 1.
#
# First, you should upload the 'problem3' directory onto a location of your choosing in Drive and run the following to have access to the code within it:

# %%
# from google.colab import drive

# drive.mount('/content/drive', force_remount=True)

# # enter the foldername in your Drive where you have saved the unzipped
# # 'pset3/code/problem 3' folder containing the '.py' files needed for this problem
# # e.g. 'cs231a/representation_learning':
# FOLDERNAME = None

# assert FOLDERNAME is not None, "[!] Enter the foldername."

# %cd drive/My\ Drive
# %cd $FOLDERNAME

# %%
import problem3
# Out:
# Import works!

# %% [markdown]
# If the above import of problem3 works, you are ready to get going with the rest of this problem! Before that, let's make sure you allocate a GPU so that code runs faster: click Runtime -> Change runtime type -> Hardware Accelerator -> GPU and your Colab instance will automatically be backed by GPU compute.

# %% [markdown]
# # PyTorch MNIST Data Preparation
#
# First, let's get the data prepared. Luckily, PyTorch has a handy function to download it for us in its [torchvision.datasets](https://pytorch.org/docs/stable/torchvision/datasets.html#cifar) package:

# %%
# Download MNIST dataset from PyTorch 
import torch
import torchvision
import torchvision.transforms as transforms

transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.1307,), (0.3081,)),
                              ])
PATH_TO_STORE_DATA = 'data/'
torchvision.datasets.MNIST(PATH_TO_STORE_DATA, download=True, train=True, 
                                             transform=transform)
torchvision.datasets.MNIST(PATH_TO_STORE_DATA, download=True, train=False, 
                                            transform=transform)
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: data/
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )

# %% [markdown]
# Now that we have downloaded the data, we will implement a PyTorch [Dataset](https://pytorch.org/tutorials/beginner/data_loading_tutorial.html) so that we can load subsets of the full MNIST dataset and use either digit identity or digit rotation as the label for a given image. Fill in the requisite bits of code in data.py (marked with TODO), (you can either do so directly through the file explorer on the left or do so locally and re-upload it), and try to execute the following:

# %%
from importlib import reload  
import problem3.data

# %% [markdown]
# Now, let's create an instance of this Dataset for training MNIST digit classification. We will create two versions of the training dataset, one with all the data and one with a small subset. If you have bugs in your code, simply modify data.py further (you can either do so directly through the file explorer on the left or do so locally and re-upload it).

# %%
problem3.data = reload(problem3.data) #reload for making changes during debugging
train_full_dataset = problem3.data.MNISTDataset('data/MNIST/processed/training.pt', 
                                          pct=1.0, classify_digit_type=True)
test_full_dataset = problem3.data.MNISTDataset('data/MNIST/processed/test.pt', 
                                         pct=1.0, classify_digit_type=True)
print('Full dataset: {0} Training Samples | {1} Test Samples'.format(
    len(train_full_dataset), len(test_full_dataset)))
train_small_dataset = problem3.data.MNISTDataset('data/MNIST/processed/training.pt', 
                                          pct=0.01, classify_digit_type=True)
print('Small train dataset: {0} Training Samples'.format(len(train_small_dataset)))
# Out:
# Full dataset: 60000 Training Samples | 10000 Test Samples
# Small train dataset: 600 Training Samples

# %% [markdown]
# Let's use the handy show_batch function to get an idea of what's in the dataset:

# %%
train_full_dataset.show_batch()

# %% [markdown]
# # PyTorch Vision Model
#
# Next, we need to define our neural net architectures for training on the data. Because we want to ultimately train for two objects (digit classification and rotation classification), we will do this via several classes so that the weights gotten from representation learning can be re-used later for more efficient digit classification.
# Fill in the marked portions of models.py, and try to execute the following:

# %%
import problem3.models
problem3.models = reload(problem3.models) #reload for making changes during debugging

image_embed_net = problem3.models.ImageEmbedNet().cuda()
classify_net = problem3.models.ClassifyNet(10).cuda()
mnist_classify_model = problem3.models.ImageClassifyModel(image_embed_net, 
                                                          classify_net)

# %% [markdown]
# If running the above results in errors, revise your code in models.py the file as in the last section.

# %% [markdown]
# # Training for MNIST Digit Prediction
#
# Let's now implement a method for training on the dataset with the models we defined above. We will create a re-usable function that can be used for both representation learning and learning to classify MNIST digits. This will involve the following:
# *   Given the dataset, creating a PyTorch [DataLoader](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader) which can take care of shuffling the dataset as well as combining multiple image.
# *   Creating a PyTorch loss function that can be used for optimizing our model for the task of classification. We will use the standard [Cross Entropy Loss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html).
# *   Creating a PyTorch [optimizer](https://pytorch.org/docs/stable/optim.html) to update the weights of the model given the loss computation.
# *   Lastly, our two training loops (one for the number of epochs, and one for iterating over the dataset) in which we use all the above to train the model.
#
# Fill in the relevant portions of code in training.py, and try to execute the following to go ahead and train on the MNIST digit classification task. If training.py is finished, we now just need to call its train function:

# %%
import problem3.training

problem3.training = reload(problem3.training)
# Create fresh models before every run to make sure we start from scratch
image_embed_net = problem3.models.ImageEmbedNet().cuda()
classify_net = problem3.models.ClassifyNet(10).cuda()
mnist_classify_model = problem3.models.ImageClassifyModel(image_embed_net, 
                                                          classify_net)

problem3.training.train(train_full_dataset, mnist_classify_model, 16, 10)
# Out:
# Epoch 0 - Training loss: 2.313 , Training Accuracy: 0.097
# Epoch 1 - Training loss: 0.686 , Training Accuracy: 0.776
# Epoch 2 - Training loss: 0.115 , Training Accuracy: 0.965
# Epoch 3 - Training loss: 0.078 , Training Accuracy: 0.976
# Epoch 4 - Training loss: 0.062 , Training Accuracy: 0.981
# Epoch 5 - Training loss: 0.052 , Training Accuracy: 0.984
# Epoch 6 - Training loss: 0.045 , Training Accuracy: 0.987
# Epoch 7 - Training loss: 0.039 , Training Accuracy: 0.988
# Epoch 8 - Training loss: 0.035 , Training Accuracy: 0.989
# Epoch 9 - Training loss: 0.031 , Training Accuracy: 0.990

# %% [markdown]
# You should get training accuracy of at least 0.98. With the model now trained, let's implement a test function and call it to see how well it works on the test set. Finish the marked portions in testing.py and run the following:

# %%
import problem3.testing

problem3.testing = reload(problem3.testing)
problem3.testing.test(test_full_dataset, mnist_classify_model, 16)
# Out:
# Testing Accuracy: 0.986

# %% [markdown]
# You should get test set accuracy similar to the train set accuracy.
# Now, let's try training on the smaller train set, and see how well the model can work on the test set.

# %%
image_embed_net = problem3.models.ImageEmbedNet().cuda()
classify_net = problem3.models.ClassifyNet(10).cuda()
mnist_classify_model = problem3.models.ImageClassifyModel(image_embed_net, classify_net)
problem3.training.train(train_small_dataset, mnist_classify_model, 16, 10)
problem3.testing.test(test_full_dataset, mnist_classify_model, 16)
# Out:
# Epoch 0 - Training loss: 2.313 , Training Accuracy: 0.080
# Epoch 1 - Training loss: 2.312 , Training Accuracy: 0.080
# Epoch 2 - Training loss: 2.310 , Training Accuracy: 0.077
# Epoch 3 - Training loss: 2.307 , Training Accuracy: 0.075
# Epoch 4 - Training loss: 2.305 , Training Accuracy: 0.112
# Epoch 5 - Training loss: 2.303 , Training Accuracy: 0.112
# Epoch 6 - Training loss: 2.301 , Training Accuracy: 0.140
# Epoch 7 - Training loss: 2.299 , Training Accuracy: 0.217
# Epoch 8 - Training loss: 2.297 , Training Accuracy: 0.192
# Epoch 9 - Training loss: 2.295 , Training Accuracy: 0.127
# Testing Accuracy: 0.125

# %% [markdown]
# You should get both low training and testing accuracy, since we are not training with much less data. If we iterate over the data for more epochs it is possible to get better results, but still far below the accuracy gotten with the full dataset:

# %%
image_embed_net = problem3.models.ImageEmbedNet().cuda()
classify_net = problem3.models.ClassifyNet(10).cuda()
mnist_classify_model = problem3.models.ImageClassifyModel(image_embed_net, classify_net)
problem3.training.train(train_small_dataset, mnist_classify_model, 16, 100)
problem3.testing.test(test_full_dataset, mnist_classify_model, 16)
# Out:
# Epoch 0 - Training loss: 2.312 , Training Accuracy: 0.100
# Epoch 1 - Training loss: 2.310 , Training Accuracy: 0.100
# Epoch 2 - Training loss: 2.305 , Training Accuracy: 0.100
# Epoch 3 - Training loss: 2.301 , Training Accuracy: 0.100
# Epoch 4 - Training loss: 2.296 , Training Accuracy: 0.100
# Epoch 5 - Training loss: 2.291 , Training Accuracy: 0.100
# Epoch 6 - Training loss: 2.285 , Training Accuracy: 0.100
# Epoch 7 - Training loss: 2.278 , Training Accuracy: 0.108
# Epoch 8 - Training loss: 2.270 , Training Accuracy: 0.175
# Epoch 9 - Training loss: 2.260 , Training Accuracy: 0.258
# Epoch 10 - Training loss: 2.246 , Training Accuracy: 0.310
# Epoch 11 - Training loss: 2.227 , Training Accuracy: 0.373
# Epoch 12 - Training loss: 2.196 , Training Accuracy: 0.465
# Epoch 13 - Training loss: 2.140 , Training Accuracy: 0.548
# Epoch 14 - Training loss: 2.033 , Training Accuracy: 0.545
# Epoch 15 - Training loss: 1.824 , Training Accuracy: 0.542
# Epoch 16 - Training loss: 1.481 , Training Accuracy: 0.598
# Epoch 17 - Training loss: 1.111 , Training Accuracy: 0.672
# Epoch 18 - Training loss: 0.885 , Training Accuracy: 0.715
# Epoch 19 - Training loss: 0.755 , Training Accuracy: 0.740
# Epoch 20 - Training loss: 0.657 , Training Accuracy: 0.775
# Epoch 21 - Training loss: 0.581 , Training Accuracy: 0.797
# Epoch 67 - Training loss: 0.042 , Training Accuracy: 0.988
# Epoch 68 - Training loss: 0.040 , Training Accuracy: 0.990
# Epoch 69 - Training loss: 0.035 , Training Accuracy: 0.992
# Epoch 70 - Training loss: 0.038 , Training Accuracy: 0.990
# Epoch 71 - Training loss: 0.037 , Training Accuracy: 0.988
# Epoch 72 - Training loss: 0.030 , Training Accuracy: 0.992
# Epoch 73 - Training loss: 0.030 , Training Accuracy: 0.995
# Epoch 74 - Training loss: 0.035 , Training Accuracy: 0.993
# Epoch 75 - Training loss: 0.028 , Training Accuracy: 0.993
# Epoch 76 - Training loss: 0.023 , Training Accuracy: 0.997
# Epoch 77 - Training loss: 0.019 , Training Accuracy: 0.998
# Epoch 78 - Training loss: 0.019 , Training Accuracy: 0.998
# Epoch 79 - Training loss: 0.016 , Training Accuracy: 0.998
# Epoch 80 - Training loss: 0.013 , Training Accuracy: 0.998
# Epoch 81 - Training loss: 0.011 , Training Accuracy: 0.998
# Epoch 82 - Training loss: 0.010 , Training Accuracy: 0.998
# Epoch 83 - Training loss: 0.010 , Training Accuracy: 0.998
# Epoch 84 - Training loss: 0.009 , Training Accuracy: 0.998
# Epoch 85 - Training loss: 0.008 , Training Accuracy: 0.998
# Epoch 86 - Training loss: 0.008 , Training Accuracy: 0.998
# Epoch 87 - Training loss: 0.007 , Training Accuracy: 0.998
# Epoch 88 - Training loss: 0.006 , Training Accuracy: 1.000
# Epoch 89 - Training loss: 0.006 , Training Accuracy: 1.000
# Epoch 90 - Training loss: 0.005 , Training Accuracy: 1.000
# Epoch 91 - Training loss: 0.005 , Training Accuracy: 1.000
# Epoch 92 - Training loss: 0.005 , Training Accuracy: 1.000
# Epoch 93 - Training loss: 0.004 , Training Accuracy: 1.000
# Epoch 94 - Training loss: 0.004 , Training Accuracy: 1.000
# Epoch 95 - Training loss: 0.004 , Training Accuracy: 1.000
# Epoch 96 - Training loss: 0.004 , Training Accuracy: 1.000
# Epoch 97 - Training loss: 0.004 , Training Accuracy: 1.000
# Epoch 98 - Training loss: 0.003 , Training Accuracy: 1.000
# Epoch 99 - Training loss: 0.003 , Training Accuracy: 1.000
# Testing Accuracy: 0.908

# %% [markdown]
# # Representation Learning via Rotation Classification

# %% [markdown]
# Now, let's define new datasets for doing our representation learning by predicting the rotation of MNIST digits, and once again call show_batch to get a look at the data:

# %%
problem3.data = reload(problem3.data) #reload for making changes during debugging

train_rotation_dataset = problem3.data.MNISTDataset('data/MNIST/processed/training.pt', 
                                          pct=1.0, classify_digit_type=False)
test_rotation_dataset = problem3.data.MNISTDataset('data/MNIST/processed/test.pt', 
                                         pct=1.0, classify_digit_type=False)
train_rotation_dataset.show_batch()

# %% [markdown]
# Now, let's train a model on the rotation prediction task by once again using our train function:

# %%
rotation_image_embed_net = problem3.models.ImageEmbedNet().cuda()
rotation_classify_net = problem3.models.ClassifyNet(8).cuda()
mnist_rotation_classify_model = problem3.models.ImageClassifyModel(rotation_image_embed_net, 
                                                   rotation_classify_net)
problem3.training.train(train_rotation_dataset, mnist_rotation_classify_model, 16, 10)
# Out:
# Epoch 0 - Training loss: 2.087 , Training Accuracy: 0.112
# Epoch 1 - Training loss: 1.036 , Training Accuracy: 0.606
# Epoch 2 - Training loss: 0.388 , Training Accuracy: 0.861
# Epoch 3 - Training loss: 0.195 , Training Accuracy: 0.932
# Epoch 4 - Training loss: 0.067 , Training Accuracy: 0.977
# Epoch 5 - Training loss: 0.054 , Training Accuracy: 0.981
# Epoch 6 - Training loss: 0.049 , Training Accuracy: 0.983
# Epoch 7 - Training loss: 0.043 , Training Accuracy: 0.985
# Epoch 8 - Training loss: 0.041 , Training Accuracy: 0.986
# Epoch 9 - Training loss: 0.038 , Training Accuracy: 0.987

# %% [markdown]
# We should once again get testing accuracy similar to training accuracy: (at least 0.95):

# %%
problem3.testing.test(test_rotation_dataset, mnist_rotation_classify_model, 16)
# Out:
# Testing Accuracy: 0.984

# %% [markdown]
# # Fine-Tuning for MNIST digit classification

# %% [markdown]
# Now that we have pretrained our model on the rotation prediction task, let's reuse the image embed part of it to train it for the task of digit classification. We will use load_state_dict to transfer over the weights from the trained model to a new instance of it, so we can later re-use the same representation learning weights in a different setup. Let's first try it on the full dataset and see how fast it converges compared to when we did not pretrain it.

# %%
image_embed_net = problem3.models.ImageEmbedNet().cuda()
image_embed_net.load_state_dict(rotation_image_embed_net.state_dict())
classify_net = problem3.models.ClassifyNet(10).cuda()
mnist_classify_model = problem3.models.ImageClassifyModel(image_embed_net, classify_net)
problem3.training.train(train_full_dataset, mnist_classify_model, 16, 10)
# Out:
# Epoch 0 - Training loss: 2.317 , Training Accuracy: 0.092
# Epoch 1 - Training loss: 0.252 , Training Accuracy: 0.923
# Epoch 2 - Training loss: 0.080 , Training Accuracy: 0.976
# Epoch 3 - Training loss: 0.059 , Training Accuracy: 0.982
# Epoch 4 - Training loss: 0.048 , Training Accuracy: 0.986
# Epoch 5 - Training loss: 0.041 , Training Accuracy: 0.988
# Epoch 6 - Training loss: 0.036 , Training Accuracy: 0.989
# Epoch 7 - Training loss: 0.031 , Training Accuracy: 0.991
# Epoch 8 - Training loss: 0.028 , Training Accuracy: 0.992
# Epoch 9 - Training loss: 0.025 , Training Accuracy: 0.993

# %%
problem3.testing.test(test_full_dataset, mnist_classify_model, 16)
# Out:
# Testing Accuracy: 0.988

# %% [markdown]
# Now, let's try training with the small dataset again and see how well that works:

# %%
image_embed_net = problem3.models.ImageEmbedNet().cuda()
image_embed_net.load_state_dict(rotation_image_embed_net.state_dict())
classify_net = problem3.models.ClassifyNet(10).cuda()
mnist_classify_model = problem3.models.ImageClassifyModel(image_embed_net, classify_net)
problem3.training.train(train_small_dataset, mnist_classify_model, 16, 10)
problem3.testing.test(test_full_dataset, mnist_classify_model, 16)
# Out:
# Epoch 0 - Training loss: 2.334 , Training Accuracy: 0.110
# Epoch 1 - Training loss: 2.268 , Training Accuracy: 0.178
# Epoch 2 - Training loss: 2.085 , Training Accuracy: 0.395
# Epoch 3 - Training loss: 1.752 , Training Accuracy: 0.543
# Epoch 4 - Training loss: 1.269 , Training Accuracy: 0.675
# Epoch 5 - Training loss: 0.898 , Training Accuracy: 0.730
# Epoch 6 - Training loss: 0.684 , Training Accuracy: 0.797
# Epoch 7 - Training loss: 0.549 , Training Accuracy: 0.835
# Epoch 8 - Training loss: 0.457 , Training Accuracy: 0.855
# Epoch 9 - Training loss: 0.374 , Training Accuracy: 0.877
# Testing Accuracy: 0.853

# %% [markdown]
# Like before, we can train on the data for long to get better results, but as you can see above training with just 10 epochs works much better than before with the pretrained features. Still, let's see the results with 50 epochs:

# %%
image_embed_net = problem3.models.ImageEmbedNet().cuda()
image_embed_net.load_state_dict(rotation_image_embed_net.state_dict())
classify_net = problem3.models.ClassifyNet(10).cuda()
mnist_classify_model = problem3.models.ImageClassifyModel(image_embed_net, classify_net)
problem3.training.train(train_small_dataset, mnist_classify_model, 16, 50)
problem3.testing.test(test_full_dataset, mnist_classify_model, 16)
# Out:
# Epoch 0 - Training loss: 2.323 , Training Accuracy: 0.032
# Epoch 1 - Training loss: 2.295 , Training Accuracy: 0.098
# Epoch 2 - Training loss: 2.200 , Training Accuracy: 0.193
# Epoch 3 - Training loss: 2.061 , Training Accuracy: 0.277
# Epoch 4 - Training loss: 1.819 , Training Accuracy: 0.495
# Epoch 5 - Training loss: 1.361 , Training Accuracy: 0.615
# Epoch 6 - Training loss: 0.913 , Training Accuracy: 0.738
# Epoch 7 - Training loss: 0.660 , Training Accuracy: 0.807
# Epoch 8 - Training loss: 0.518 , Training Accuracy: 0.837
# Epoch 9 - Training loss: 0.418 , Training Accuracy: 0.862
# Epoch 10 - Training loss: 0.351 , Training Accuracy: 0.890
# Epoch 11 - Training loss: 0.295 , Training Accuracy: 0.918
# Epoch 12 - Training loss: 0.246 , Training Accuracy: 0.940
# Epoch 13 - Training loss: 0.213 , Training Accuracy: 0.948
# Epoch 14 - Training loss: 0.185 , Training Accuracy: 0.957
# Epoch 15 - Training loss: 0.169 , Training Accuracy: 0.958
# Epoch 16 - Training loss: 0.151 , Training Accuracy: 0.962
# Epoch 17 - Training loss: 0.137 , Training Accuracy: 0.967
# Epoch 18 - Training loss: 0.122 , Training Accuracy: 0.977
# Epoch 19 - Training loss: 0.110 , Training Accuracy: 0.980
# Epoch 20 - Training loss: 0.095 , Training Accuracy: 0.982
# Epoch 21 - Training loss: 0.083 , Training Accuracy: 0.983
# Epoch 22 - Training loss: 0.075 , Training Accuracy: 0.982
# Epoch 23 - Training loss: 0.068 , Training Accuracy: 0.983
# Epoch 24 - Training loss: 0.064 , Training Accuracy: 0.988
# Epoch 25 - Training loss: 0.060 , Training Accuracy: 0.987
# Epoch 26 - Training loss: 0.058 , Training Accuracy: 0.988
# Epoch 27 - Training loss: 0.054 , Training Accuracy: 0.988
# Epoch 28 - Training loss: 0.053 , Training Accuracy: 0.988
# Epoch 29 - Training loss: 0.050 , Training Accuracy: 0.990
# Epoch 30 - Training loss: 0.046 , Training Accuracy: 0.992
# Epoch 31 - Training loss: 0.043 , Training Accuracy: 0.993
# Epoch 32 - Training loss: 0.038 , Training Accuracy: 0.993
# Epoch 33 - Training loss: 0.032 , Training Accuracy: 1.000
# Epoch 34 - Training loss: 0.026 , Training Accuracy: 1.000
# Epoch 35 - Training loss: 0.021 , Training Accuracy: 0.998
# Epoch 36 - Training loss: 0.017 , Training Accuracy: 0.998
# Epoch 37 - Training loss: 0.016 , Training Accuracy: 0.998
# Epoch 38 - Training loss: 0.013 , Training Accuracy: 0.998
# Epoch 39 - Training loss: 0.013 , Training Accuracy: 0.998
# Epoch 40 - Training loss: 0.012 , Training Accuracy: 0.998
# Epoch 41 - Training loss: 0.011 , Training Accuracy: 0.998
# Epoch 42 - Training loss: 0.011 , Training Accuracy: 0.998
# Epoch 43 - Training loss: 0.011 , Training Accuracy: 0.998
# Epoch 44 - Training loss: 0.011 , Training Accuracy: 0.998
# Epoch 45 - Training loss: 0.011 , Training Accuracy: 0.998
# Epoch 46 - Training loss: 0.011 , Training Accuracy: 0.998
# Epoch 47 - Training loss: 0.010 , Training Accuracy: 0.998
# Epoch 48 - Training loss: 0.010 , Training Accuracy: 0.998
# Epoch 49 - Training loss: 0.010 , Training Accuracy: 0.998
# Testing Accuracy: 0.920

# %% [markdown]
# Not bad! We can also try training without optimizing for the image embedding layers, and just train the classifier part of the network.

# %%
image_embed_net = problem3.models.ImageEmbedNet().cuda()
image_embed_net.load_state_dict(rotation_image_embed_net.state_dict())
classify_net = problem3.models.ClassifyNet(10).cuda()
mnist_classify_model = problem3.models.ImageClassifyModel(image_embed_net, classify_net,
                                          exclude_embed_params=True)
problem3.training.train(train_small_dataset, mnist_classify_model, 16, 50)
problem3.testing.test(test_full_dataset, mnist_classify_model, 16)
# Out:
# Epoch 0 - Training loss: 2.300 , Training Accuracy: 0.098
# Epoch 1 - Training loss: 2.243 , Training Accuracy: 0.190
# Epoch 2 - Training loss: 2.079 , Training Accuracy: 0.360
# Epoch 3 - Training loss: 1.857 , Training Accuracy: 0.475
# Epoch 4 - Training loss: 1.560 , Training Accuracy: 0.618
# Epoch 5 - Training loss: 1.238 , Training Accuracy: 0.712
# Epoch 6 - Training loss: 0.972 , Training Accuracy: 0.798
# Epoch 7 - Training loss: 0.775 , Training Accuracy: 0.833
# Epoch 8 - Training loss: 0.634 , Training Accuracy: 0.857
# Epoch 9 - Training loss: 0.531 , Training Accuracy: 0.870
# Epoch 10 - Training loss: 0.455 , Training Accuracy: 0.887
