# %% [markdown]
# ## CS 330 Homework 3 Installation
#
# The following code blocks will install the required libraries.

# %% [markdown]
# ## Setup for Google Drive and Required Libraries

# %%
#@title Mount Google Drive
#@markdown Your work will be stored in a folder called `cs330_fall2020` by default to prevent Colab instance timeouts 
#@markdown from deleting your edits and requiring you to redownload the mujoco library. Feel free to use this if you want to write out plots.

import os
from google.colab import drive
drive.mount('/content/gdrive')

#@title set up mount symlink

DRIVE_PATH = '/content/gdrive/My\ Drive/Stanford/CS330/HW3'
DRIVE_PYTHON_PATH = DRIVE_PATH.replace('\\', '')
if not os.path.exists(DRIVE_PYTHON_PATH):
  # %mkdir $DRIVE_PATH

## the space in `My Drive` causes some issues,
## make a symlink to avoid this
SYM_PATH = '/content/cs330_hw3'
if not os.path.exists(SYM_PATH):
  # !ln -s $DRIVE_PATH $SYM_PATH
# Out:
# Mounted at /content/gdrive

# %%
#@title Install Requirements
#@markdown Requirements for the assignment and display drivers

# Robot sim
# !pip install gym==0.15.4
# !pip install pygame

# Various things for render
# !apt-get install python-opengl -y
# !apt install xvfb -y

# Rendering Environment
# !pip install pyvirtualdisplay
# !pip install piglet
# !sudo apt-get install -y xvfb ffmpeg
# !pip install imageio
# !pip install PILLOW
# Out:
# ...
#      |████████████████████████████████| 1.6MB 12.1MB/s
# ...
#      |████████████████████████████████| 1.0MB 40.6MB/s
# ...
#   Created wheel for gym: filename=gym-0.15.4-cp36-none-any.whl size=1648486 sha256=3d9924af35b217f0d9151bf2da7cc30296ec4129afd369e8d78453e8cbbb8093
#   Stored in directory: /root/.cache/pip/wheels/e9/26/9b/8a1a6599a91077a938ac4348cc3d3ac84bfab0dbfddeb4c6e7
# Successfully built gym
# ERROR: tensorflow-probability 0.11.0 has requirement cloudpickle==1.3, but you'll have cloudpickle 1.2.2 which is incompatible.
# ...
#   Found existing installation: pyglet 1.5.0
#     Uninstalling pyglet-1.5.0:
#       Successfully uninstalled pyglet-1.5.0
#   Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Found existing installation: gym 0.17.2
#     Uninstalling gym-0.17.2:
#       Successfully uninstalled gym-0.17.2
# ...
#      |████████████████████████████████| 11.4MB 9.2MB/s
# ...

# %%
#@title Download Mujoco from an online repository

MJC_PATH = '{}/mujoco'.format(SYM_PATH)
if not os.path.exists(MJC_PATH):
  # %mkdir $MJC_PATH
# %cd $MJC_PATH
if not os.path.exists(os.path.join(MJC_PATH, 'mujoco200')):
  # !wget -q https://www.roboti.us/download/mujoco200_linux.zip
  # !unzip -q mujoco200_linux.zip
  # %mv mujoco200_linux mujoco200
  # %rm mujoco200_linux.zip
# Out:
# /content/gdrive/My Drive/Stanford/CS330/HW3/mujoco

# %%
#@title Important: ACTION Required BEFORE running this cell
#@markdown Place the mujoco key we have given you into a text file called mjkey.txt 
#@markdown and ensure that the mujoco key is in the Google Drive path `cs330_fall2020/mujoco`.

import os

os.environ['LD_LIBRARY_PATH'] += ':{}/mujoco200/bin'.format(MJC_PATH)
os.environ['MUJOCO_PY_MUJOCO_PATH'] = '{}/mujoco200'.format(MJC_PATH)
os.environ['MUJOCO_PY_MJKEY_PATH'] = '{}/mjkey.txt'.format(MJC_PATH)

## installation on colab does not find *.so files
## in LD_LIBRARY_PATH, copy over manually instead
# !cp $MJC_PATH/mujoco200/bin/*.so /usr/lib/x86_64-linux-gnu/

# %%
#@title Important system updates for mujoco-py
# !apt update 
# !apt install -y --no-install-recommends \
        build-essential \
        curl \
        git \
        gnupg2 \
        make \
        cmake \
        ffmpeg \
        swig \
        libz-dev \
        unzip \
        zlib1g-dev \
        libglfw3 \
        libglfw3-dev \
        libxrandr2 \
        libxinerama-dev \
        libxi6 \
        libxcursor-dev \
        libgl1-mesa-dev \
        libgl1-mesa-glx \
        libglew-dev \
        libosmesa6-dev \
        lsb-release \
        ack-grep \
        patchelf \
        wget \
        xpra \
        xserver-xorg-dev \
        xvfb \
        python-opengl \
        ffmpeg > /dev/null 2>&1
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Get:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# ...

# %%
#@title Clone and install mujoco-py
#@markdown Remember that you need to put the key in the appropriate location as described above
# %cd $MJC_PATH
if not os.path.exists('mujoco-py'):
  # !git clone https://github.com/openai/mujoco-py.git
# %cd mujoco-py
# %pip install -e .

## cythonize at the first import
import mujoco_py
# Out:
# /content/gdrive/My Drive/Stanford/CS330/HW3/mujoco
# /content/gdrive/My Drive/Stanford/CS330/HW3/mujoco/mujoco-py
# Obtaining file:///content/gdrive/My%20Drive/Stanford/CS330/HW3/mujoco/mujoco-py
#   Installing build dependencies ... done
#   WARNING: Missing build requirements in pyproject.toml for file:///content/gdrive/My%20Drive/Stanford/CS330/HW3/mujoco/mujoco-py.
#   WARNING: The project does not specify a build backend, and pip cannot fall back to setuptools without 'wheel'.
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#   Using cached https://files.pythonhosted.org/packages/12/72/3190b7cc8494c05d7fb350237d3f51abdaff79e74d1e13d6f84df4b57f6b/glfw-2.0.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl
# ...

# %%
#@title Clone and install multiworld
# %cd $SYM_PATH
# !git clone https://github.com/vitchyr/multiworld.git

# %cd multiworld
# %pip install -e .
# Out:
# /content/gdrive/My Drive/Stanford/CS330/HW3
# fatal: destination path 'multiworld' already exists and is not an empty directory.
# /content/gdrive/My Drive/Stanford/CS330/HW3/multiworld
# Obtaining file:///content/gdrive/My%20Drive/Stanford/CS330/HW3/multiworld
# ...
#   Running setup.py develop for multiworld
# ...

# %%
#@title Sets up virtual display
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
#@title Check imports and add helper functions for display

import os
import gym
from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) # error only
import tensorflow as tf
import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay
if type(os.environ.get("DISPLAY")) is not str or len(os.environ.get("DISPLAY"))==0:
    # !bash ../xvfb start
    # %env DISPLAY=:1

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %%
#@title After running, you should see a video play
matplotlib.use('Agg')

env = wrap_env(gym.make("Ant-v2"))

observation = env.reset()
for i in range(10):
    env.render(mode='rgb_array')
    obs, rew, term, _ = env.step(env.action_space.sample() ) 
    if term:
      break;
            
env.close()
print('Loading video...')
show_video()
# Out:
# Loading video...
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
#@title Random seed is set to be fixed
import tensorflow
tensorflow.random.set_seed(330)

# %% [markdown]
# # BitFlip Goal Conditioned RL

# %% [markdown]
# ## BitFlipEnv
#
# Familiarize yourself with what the bit flip environment does and what each method does.
#
# You do *NOT* need to modify the following cell.

# %%
class BitFlipEnv():
    '''bit flipping environment for reinforcement learning.
    The environment is a 1D vector of binary values (state vector).
    At each step, the actor can flip a single bit (0 to 1 or 1 to 0).
    The goal is to flip bits until the state vector matches the
    goal vector (also a 1D vector of binary values). At each step,
    the actor receives a goal of 0 if the state and goal vector
    do not match and a reward of 1 if the state and goal vector
    match.

    Internally the state and goal vector are a numpy array, which
    allows the vectors to be printed by the show_goal and show_state
    methods. When '''

    def __init__(self, num_bits, verbose = False):
        '''Initialize new instance of BitFlip class.
        inputs: num_bits - number of bits in the environment; must
                be an integer
                verbose - prints state and goal vector after each
                          step if True'''

        # check that num_bits is a positive integer
        if (num_bits < 0) or (type(num_bits) != type(0)):
            print("Invalid number of bits -  must be positive integer")
            return

        # number of bits in the environment
        self.num_bits = num_bits
        # randomly set the state vector
        self.state_vector = np.random.randint(0, 2, num_bits)
        # randomly set the goal vector
        self.goal_vector = np.random.randint(0, 2, num_bits)
        # whether to print debugging info
        self.verbose = verbose
        # TODO set dimensions of observation space
        self.observation_space = self.state_vector
        # TODO create action space; may use gym type
        self.action_space = num_bits
        # space of the goal vector
        self.goal_space = self.goal_vector
        # number of steps taken
        self.steps = 0

        return

    def show_goal(self):
        '''Returns the goal as a numpy array. Used for debugging.'''
        return self.goal_vector

    def show_state(self):
        '''Returns the state as a numpy array. Used for debugging.'''
        return self.state_vector

    def reset(self):
        '''resets the environment. Returns a reset state_vector
        and goal_vector as tf tensors'''

        # randomly reset both the state and the goal vectors
        self.state_vector = np.random.randint(0, 2, self.num_bits)
        self.goal_vector = np.random.randint(0, 2, self.num_bits)
        self.steps = 0

        # return as np array
        return self.state_vector, self.goal_vector


    def step(self, action):
        '''take a step and flip one of the bits.

        inputs: action - integer index of the bit to flip
        outputs: state - new state_vector (tensor)
                 reward - 0 if state != goal and 1 if state == goal
                 done - boolean value indicating if the goal has been reached'''
        self.steps += 1


        if action < 0 or action >= self.num_bits:
            # check argument is in range
            print("Invalid action! Must be integer ranging from \
                0 to num_bits-1")
            return

        # flip the bit with index action
        if self.state_vector[action] == 1:
            self.state_vector[action] = 0
        else:
            self.state_vector[action] = 1

        # initial values of reward and done - may change
        # depending on state and goal vectors
        reward = 0
        done = True

        # check if state and goal vectors are identical
        if False in (self.state_vector == self.goal_vector):
            reward = -1
            done = False

        # print additional info if verbose mode is on
        if self.verbose:
            print("Bit flipped:   ", action)
            print("Goal vector:   ", self.goal_vector)
            print("Updated state: ", self.state_vector)
            print("Reward:        ", reward)

        if done:
            #print("Solved in: ", self.steps)
            pass

        # return state as numpy arrays
        # return goal_vector in info field
        return np.copy(self.state_vector), reward, done, self.steps

# %% [markdown]
# ## Buffer
# Familiarize yourself with what the buffer does
#
# You do *NOT* need to modify the following cell.

# %%
import numpy as np
import random
from collections import deque 

class Buffer(object) :

	def __init__(self,size,sample_size):

		self.size = size
		self.sample_size = sample_size
		self.buffer = deque()

	def add(self,state,action,reward,next_state,goal_state) :
		self.buffer.append((state,action,reward,next_state,goal_state))

		if len(self.buffer) > self.size:
			self.buffer.popleft()

	def sample(self) :
		if len(self.buffer) < self.sample_size:
			samples = self.buffer
		else:	
			samples = random.sample(self.buffer,self.sample_size)
		
		state = np.reshape(np.array([arr[0] for arr in samples]),[len(samples),-1])
		action = np.array([arr[1] for arr in samples])
		reward = np.array([arr[2] for arr in samples])
		next_state = np.reshape(np.array([arr[3] for arr in samples]),[len(samples),-1])
		goal_state = np.reshape(np.array([arr[4] for arr in samples]),[len(samples),-1])

		return state, action, reward, next_state, goal_state

# %% [markdown]
# ## BitFlip Goal Condition RL and Training
#
# Implement the changes you need for Problems 1-3 here in the cells below.

# %%
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt


class Model(tf.keras.Model):

  def __init__(self, num_bits):
    super(Model, self).__init__()

    hidden_dim = 256
    self.dense1 = tf.keras.layers.Dense(hidden_dim, activation=tf.nn.relu)
    self.out = tf.keras.layers.Dense(num_bits,activation = None)

  def call(self, inputs):

    x = self.dense1(inputs)
    return self.out(x)

# %%
# ************   Helper functions    ************ #

def updateTarget(model, target_model) :
    target_model.set_weights(model.get_weights()) 

def solve_environment(num_bits, model, bit_env, state, goal_state, total_reward):
    '''attempt to solve the bit flipping environment using the current policy

    inputs: num_bits - number of bits to be looped over 
        model - DQN to run prediction on
        bit_env - environment for bitflip
        state - current state
        goal_state - desired state
        total_reward - cumulative reward so far
    '''
    
    # list for recording what happened in the episode
    episode_experience = []
    succeeded = False

    for t in range(num_bits):
        # attempt to solve the state - number of steps given to solve the
        # state is equal to the passed argument steps_per_episode.

        # make the model goal conditioned by concatenating current state with goal state
        inputs = np.concatenate((state, goal_state))
        inputs = np.expand_dims(inputs, axis=0)
        # forward pass to find action
        out = model(inputs)
        action = np.argmax(out,axis = 1)
        # take the action
        next_state,reward,done, _ = bit_env.step(action)
        # add to the episode experience (what happened)
        episode_experience.append((state,action,reward,next_state,goal_state))
        # calculate total reward
        total_reward+=reward
        # update state
        state = next_state
        # mark that we've finished the episode and succeeded with training
        if done:
            if succeeded:
                continue
            else:
                succeeded = True

    return succeeded, episode_experience, total_reward

def solve_environment_no_goal(num_bits, model, bit_env, state, goal_state, total_reward):
    '''attempt to solve the bit_flip env using no goal'''
    
    # list for recording what happened in the episode
    episode_experience = []
    succeeded = False

    for t in range(num_bits):
        # attempt to solve the state - number of steps given to solve the
        # state is equal to the passed argument steps_per_episode.

        inputs = state
        inputs = np.expand_dims(inputs, axis=0)
        # forward pass to find action
        out = model(inputs)
        action = np.argmax(out,axis = 1)
        # take the action
        next_state,reward,done, _ = bit_env.step(action)
        # add to the episode experience (what happened)
        episode_experience.append((state,action,reward,next_state,goal_state))
        # calculate total reward
        total_reward+=reward
        # update state
        state = next_state
        # mark that we've finished the episode and succeeded with training
        if done:
            if succeeded:
                continue
            else:
                succeeded = True

    return succeeded, episode_experience, total_reward


def update_replay_buffer(num_bits, num_relabeled, replay_buffer, episode_experience, HER):
    '''adds past experience to the replay buffer. Training is done with episodes from the replay
    buffer. When HER is used, relabeled experiences are also added to the replay buffer

    inputs: num_bits - number of bits to be looped over 
            replay_buffer - the buffer to store past experience in
            episode_experience - list of transitions from the last episode
            HER -  type of hindsight experience replay to use
    modifies: replay_buffer
    outputs: None'''

    for t in range(num_bits) :
        # copy actual experience from episode_experience to replay_buffer
        s,a,r,s_,g = episode_experience[t]
        # state
        inputs = s,
        # next state
        inputs_ = s_
        # add actual experience to the replay buffer
        replay_buffer.add(inputs,a,r,inputs_,g)

        # reward for success and failure
        reward_failure = -1
        reward_success = 0

        # when HER is used, each call to update_replay_buffer should add num_relabeled
        # relabeled points to the replay buffer

        if HER == 'None':
            # If HER not being used, then use the actual goal state
            pass

        elif HER == 'final':
            # final - relabel based on final state in episode
            # pretend that final state in this episode is the goal and add to buffer
            _,_,_,s_goal_,_ = episode_experience[-1]
            # check if state and goal vectors are identical
            if False in (inputs_ == s_goal_):
              replay_buffer.add(inputs,a,reward_failure,inputs_,s_goal_)
            else:
              replay_buffer.add(inputs,a,reward_success,inputs_,s_goal_)

        elif HER == 'future':
            # future - relabel based on future state. At each timestep t, relabel the
            # goal with a randomly select timestep between t and the end of the
            # episode
            for t_ in range(num_relabeled):
              # relabel this experience with a randomly chosen future experience as goal
              goal_idx = np.random.randint(t, num_bits, 1)
              # get goal state randomly from a future experience in current episode
              _,_,_,s_goal_,_ = episode_experience[goal_idx[0]]

              # check if state and goal vectors are identical
              if False in (inputs_ == s_goal_):
                replay_buffer.add(inputs,a,reward_failure,inputs_,s_goal_)
              else:
                replay_buffer.add(inputs,a,reward_success,inputs_,s_goal_)

        elif HER == 'random':
            # random - relabel based on a random state in the episode
            for t_ in range(num_relabeled):
              # relabel this experience with a randomly chosen future experience as goal
              goal_idx = np.random.randint(0, num_bits, 1)
              # get goal state randomly from a future experience in current episode
              s_goal,_,_,s_goal_,_ = episode_experience[goal_idx[0]]

              # check if state and goal vectors are identical
              if False in (inputs_ == s_goal_):
                replay_buffer.add(inputs,a,reward_failure,inputs_,s_goal_)
              else:
                replay_buffer.add(inputs,a,reward_success,inputs_,s_goal_)

        else:
            print("Invalid value for Her flag - HER not used")
    return

# %%
import csv
# ************   Main training loop    ************ #


def flip_bits(num_bits, num_epochs, buffer_size = 1e6, batch_size = 128, 
              num_episodes = 16, num_relabeled = 4, gamma = 0.98, log_interval=5, opt_steps=40, HER = "None",
              logdir='logs', logfile='log.csv'):
    '''Main loop for running in the bit flipping environment. The DQN is
    trained over num_epochs. In each epoch, the agent runs in the environment
    num_episodes number of times. The Q-target and Q-policy networks are
    updated at the end of each epoch. Within one episode, Q-policy attempts
    to solve the environment and is limited to the same number as steps as the
    size of the environment

    inputs: HER - string specifying whether to use HER'''

    print("Running bit flip environment with %d bits and HER policy: %s" %(num_bits, HER))

    # csv writer to log accuracies
    print('Logging to -> {}'.format(os.path.join(SYM_PATH,logdir,logfile)))
    if not os.path.exists(os.path.join(SYM_PATH,logdir)):
      os.system('mkdir -p {}'.format(os.path.join(SYM_PATH,logdir)))

    with open(os.path.join(SYM_PATH,logdir,logfile), 'w', newline='') as csvfile:
      fieldnames = ['epoch',            \
                    'cumulative_reward',\
                    'success_rate',     \
                    'mean_loss'         ]
      # write header
      csv_writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      csv_writer.writeheader()

      # create bit flipping environment and replay buffer
      bit_env = BitFlipEnv(num_bits)
      replay_buffer = Buffer(buffer_size,batch_size)

      # set up Q-policy (model) and Q-target (target_model)
      model = Model(num_bits)
      optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3)
      target_model = Model(num_bits)

      # make the model goal conditioned by concatenating goal state to the input
      state, goal_state = bit_env.reset()      
      # inputs = state
      inputs = np.concatenate((state, goal_state)) # goal conditioned
      
      inputs = np.expand_dims(inputs, axis=0)  
      model(inputs)
      target_model(inputs)

      # start by making Q-target and Q-policy the same
      updateTarget(model, target_model)

      total_loss = []                  # training loss for each epoch
      success_rate = []                # success rate for each epoch
      
      for i in range(num_epochs):
          # Run for a fixed number of epochs

          total_reward = 0.0           # total reward for the epoch
          successes = []               # record success rate for each episode of the epoch
          losses = []                  # loss at the end of each epoch

          for k in range(num_episodes):
              # Run in the environment for num_episodes  
              state, goal_state = bit_env.reset()             # reset the environment     
              # attempt to solve the environment
              # modify to be goal conditioned
              succeeded, episode_experience, total_reward = solve_environment(num_bits, model, bit_env, state, goal_state, total_reward)
              successes.append(succeeded)                     # track whether we succeeded in environment 
              update_replay_buffer(num_bits, num_relabeled, replay_buffer, episode_experience, HER)   # add to the replay buffer; use specified  HER policy
          for k in range(opt_steps):
              # optimize the Q-policy network

              # sample from the replay buffer
              state,action,reward,next_state,goal_state = replay_buffer.sample()
              # forward pass through target network   
              # inputs = state
              inputs = np.concatenate((state, goal_state), axis=-1) # goal conditioned
              inputs_ = np.concatenate((next_state, goal_state), axis=-1) # goal conditioned
              with tf.GradientTape() as tape:
                target_net_Q = target_model(inputs_)
                # calculate target reward
                target_reward = np.clip(np.reshape(reward,[-1]) + gamma * np.reshape(np.max(target_net_Q,axis = -1),[-1]),-1. / (1 - gamma), 0)
                # calculate predictions and loss
                model_predict = model(inputs)
                model_action_taken = np.reshape(action,[-1])
                action_one_hot = tf.one_hot(model_action_taken, num_bits)
                Q_val = tf.reduce_sum(model_predict * action_one_hot, axis=1)
                loss = tf.reduce_mean(tf.square(Q_val - target_reward))
                losses.append(loss)
              
              gradients = tape.gradient(loss, model.trainable_variables)
              optimizer.apply_gradients(zip(gradients, model.trainable_variables))
              
          updateTarget(model, target_model)               # update target model by copying Q-policy to Q-target      
          success_rate.append(np.mean(successes))       # append mean success rate for this epoch

          # write to csv file
          csv_writer.writerow({'epoch'              : i,                    
                               'cumulative_reward'  : total_reward,       
                               'success_rate'       : np.mean(successes), 
                               'mean_loss'          : np.mean(losses)     })
          
          if i % log_interval == 0:
              print('Epoch: %d  Cumulative reward: %f  Success rate: %.4f Mean loss: %.4f' % (i, total_reward, np.mean(successes), np.mean(losses)))
                  
    return success_rate

# %%
# Sample commands have been provided to you below
# run with type of HER specified
exp_name = 'log_no_goal_no_HER'
logdir = 'logs'
success_rate  = flip_bits(num_bits=7, num_epochs=150, HER='None', logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 7 bits and HER policy: None
# Logging to -> /content/cs330_hw3/logs/log_no_goal_no_HER.csv
# Epoch: 0  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.2527
# Epoch: 5  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1752
# Epoch: 10  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1219
# Epoch: 15  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1034
# Epoch: 20  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0862
# Epoch: 25  Cumulative reward: -109.000000  Success rate: 0.0625 Mean loss: 0.0669
# Epoch: 30  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0623
# Epoch: 35  Cumulative reward: -110.000000  Success rate: 0.0625 Mean loss: 0.0513
# Epoch: 40  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0405
# Epoch: 45  Cumulative reward: -111.000000  Success rate: 0.0625 Mean loss: 0.0356
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_no_goal_no_HER.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
# Sample commands have been provided to you below
# run with type of HER specified
exp_name = 'log_goal_conditioned_no_HER'
logdir = 'logs'
success_rate  = flip_bits(num_bits=7, num_epochs=150, HER='None', logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 7 bits and HER policy: None
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned_no_HER.csv
# Epoch: 0  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1674
# Epoch: 5  Cumulative reward: -108.000000  Success rate: 0.0625 Mean loss: 0.1426
# Epoch: 10  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1169
# Epoch: 15  Cumulative reward: -111.000000  Success rate: 0.0625 Mean loss: 0.0999
# Epoch: 20  Cumulative reward: -106.000000  Success rate: 0.1250 Mean loss: 0.0913
# Epoch: 25  Cumulative reward: -110.000000  Success rate: 0.0625 Mean loss: 0.0711
# Epoch: 30  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0683
# Epoch: 35  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0574
# Epoch: 40  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0519
# Epoch: 45  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0453
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned_no_HER.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
n_bits = 7
her_type = 'None'
n_epochs = 250
exp_name = 'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}'.format(n_bits, her_type, n_epochs)
logdir = 'logs'
success_rate  = flip_bits(num_bits=n_bits, num_epochs=n_epochs, HER=her_type, logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 7 bits and HER policy: None
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned.n_bits_7.HER_None.epochs_250.csv
# Epoch: 0  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1672
# Epoch: 5  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1231
# Epoch: 10  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1109
# Epoch: 15  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.1012
# Epoch: 20  Cumulative reward: -110.000000  Success rate: 0.0625 Mean loss: 0.0899
# Epoch: 25  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0786
# Epoch: 30  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0656
# Epoch: 35  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0583
# Epoch: 40  Cumulative reward: -112.000000  Success rate: 0.0000 Mean loss: 0.0501
# Epoch: 45  Cumulative reward: -109.000000  Success rate: 0.0625 Mean loss: 0.0476
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_7.HER_None.epochs_250.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
n_bits = 7
her_type = 'final'
n_epochs = 250
exp_name = 'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}'.format(n_bits, her_type, n_epochs)
logdir = 'logs'
success_rate  = flip_bits(num_bits=n_bits, num_epochs=n_epochs, HER=her_type, logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 7 bits and HER policy: final
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned.n_bits_7.HER_final.epochs_250.csv
# Epoch: 0  Cumulative reward: -105.000000  Success rate: 0.1250 Mean loss: 0.1956
# Epoch: 5  Cumulative reward: -106.000000  Success rate: 0.1250 Mean loss: 0.2068
# Epoch: 10  Cumulative reward: -109.000000  Success rate: 0.0625 Mean loss: 0.1680
# Epoch: 15  Cumulative reward: -110.000000  Success rate: 0.0625 Mean loss: 0.1536
# Epoch: 20  Cumulative reward: -103.000000  Success rate: 0.2500 Mean loss: 0.1283
# Epoch: 25  Cumulative reward: -89.000000  Success rate: 0.5000 Mean loss: 0.1236
# Epoch: 30  Cumulative reward: -77.000000  Success rate: 0.8125 Mean loss: 0.1154
# Epoch: 35  Cumulative reward: -81.000000  Success rate: 0.8750 Mean loss: 0.0962
# Epoch: 40  Cumulative reward: -75.000000  Success rate: 1.0000 Mean loss: 0.0720
# Epoch: 45  Cumulative reward: -68.000000  Success rate: 0.9375 Mean loss: 0.0723
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_7.HER_final.epochs_250.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
#@title Compare
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(7,'None',250)),
             os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(7,'final',250))]

legends = ['7bits_HER_None_250epochs_raw',
           '7bits_HER_None_250epochs_avg',
           '7bits_HER_final_250epochs_raw',
           '7bits_HER_final_250epochs_avg']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, 'compare_goal_conditioned.n_bits_{}_{}.HER_{}_{}.epochs_{}_{}.png'.format(7,7,'None','final',250,250))

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_7.HER_None.epochs_250.csv
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_7.HER_final.epochs_250.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:52: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
n_bits = 15
her_type = 'None'
n_epochs = 500
exp_name = 'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}'.format(n_bits, her_type, n_epochs)
logdir = 'logs'
success_rate  = flip_bits(num_bits=n_bits, num_epochs=n_epochs, HER=her_type, logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 15 bits and HER policy: None
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_None.epochs_500.csv
# Epoch: 0  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1090
# Epoch: 5  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0883
# Epoch: 10  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0828
# Epoch: 15  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0894
# Epoch: 20  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0884
# Epoch: 25  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0744
# Epoch: 30  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0706
# Epoch: 35  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0575
# Epoch: 40  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0576
# Epoch: 45  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0522
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_None.epochs_500.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
n_bits = 15
her_type = 'final'
n_epochs = 500
exp_name = 'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}'.format(n_bits, her_type, n_epochs)
logdir = 'logs'
success_rate  = flip_bits(num_bits=n_bits, num_epochs=n_epochs, HER=her_type, logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 15 bits and HER policy: final
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_final.epochs_500.csv
# Epoch: 0  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1049
# Epoch: 5  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1571
# Epoch: 10  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1498
# Epoch: 15  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1404
# Epoch: 20  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1272
# Epoch: 25  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1245
# Epoch: 30  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1341
# Epoch: 35  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1265
# Epoch: 40  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1289
# Epoch: 45  Cumulative reward: -235.000000  Success rate: 0.0625 Mean loss: 0.1268
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_final.epochs_500.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
#@title Compare
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(15,'None',500)),
             os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(15,'final',500))]

legends = ['15bits_HER_None_500epochs_raw',
           '15bits_HER_None_500epochs_avg',
           '15bits_HER_final_500epochs_raw',
           '15bits_HER_final_500epochs_avg']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, 'compare_goal_conditioned.n_bits_{}_{}.HER_{}_{}.epochs_{}_{}.png'.format(15,15,'None','final',500,500))

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_None.epochs_500.csv
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_final.epochs_500.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:52: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
n_bits = 25
her_type = 'None'
n_epochs = 1000
exp_name = 'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}'.format(n_bits, her_type, n_epochs)
logdir = 'logs'
success_rate  = flip_bits(num_bits=n_bits, num_epochs=n_epochs, HER=her_type, logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 25 bits and HER policy: None
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned.n_bits_25.HER_None.epochs_1000.csv
# Epoch: 0  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1047
# Epoch: 5  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0599
# Epoch: 10  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0686
# Epoch: 15  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0674
# Epoch: 20  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0658
# Epoch: 25  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0666
# Epoch: 30  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0751
# Epoch: 35  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0615
# Epoch: 40  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0559
# Epoch: 45  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0537
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_25.HER_None.epochs_1000.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
n_bits = 25
her_type = 'final'
n_epochs = 1000
exp_name = 'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}'.format(n_bits, her_type, n_epochs)
logdir = 'logs'
success_rate  = flip_bits(num_bits=n_bits, num_epochs=n_epochs, HER=her_type, logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 25 bits and HER policy: final
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned.n_bits_25.HER_final.epochs_1000.csv
# Epoch: 0  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.0964
# Epoch: 5  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1392
# Epoch: 10  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1276
# Epoch: 15  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1221
# Epoch: 20  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1213
# Epoch: 25  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1125
# Epoch: 30  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1131
# Epoch: 35  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1117
# Epoch: 40  Cumulative reward: -400.000000  Success rate: 0.0000 Mean loss: 0.1085
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_25.HER_final.epochs_1000.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
#@title Compare
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(25,'None',1000)),
             os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(25,'final',1000))]

legends = ['25bits_HER_None_1000epochs_raw',
           '25bits_HER_None_1000epochs_avg',
           '25bits_HER_final_1000epochs_raw',
           '25bits_HER_final_1000epochs_avg']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, 'compare_goal_conditioned.n_bits_{}_{}.HER_{}_{}.epochs_{}_{}.png'.format(25,25,'None','final',1000,1000))

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_25.HER_None.epochs_1000.csv
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_25.HER_final.epochs_1000.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:52: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
n_bits = 15
her_type = 'future'
n_epochs = 500
exp_name = 'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}'.format(n_bits, her_type, n_epochs)
logdir = 'logs'
success_rate  = flip_bits(num_bits=n_bits, num_epochs=n_epochs, HER=her_type, logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 15 bits and HER policy: future
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_future.epochs_500.csv
# Epoch: 0  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.0963
# Epoch: 5  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.2168
# Epoch: 10  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1996
# Epoch: 15  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1697
# Epoch: 20  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1464
# Epoch: 25  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1252
# Epoch: 30  Cumulative reward: -235.000000  Success rate: 0.0625 Mean loss: 0.1108
# Epoch: 35  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1062
# Epoch: 40  Cumulative reward: -229.000000  Success rate: 0.1250 Mean loss: 0.0968
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_future.epochs_500.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
n_bits = 15
her_type = 'random'
n_epochs = 500
exp_name = 'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}'.format(n_bits, her_type, n_epochs)
logdir = 'logs'
success_rate  = flip_bits(num_bits=n_bits, num_epochs=n_epochs, HER=her_type, logdir=logdir, logfile=exp_name+'.csv') 
# pass success rate for each run as first argument and labels as second list
# Out:
# Running bit flip environment with 15 bits and HER policy: random
# Logging to -> /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_random.epochs_500.csv
# Epoch: 0  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1293
# Epoch: 5  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.2292
# Epoch: 10  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1984
# Epoch: 15  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1758
# Epoch: 20  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1475
# Epoch: 25  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1332
# Epoch: 30  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1241
# Epoch: 35  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1176
# Epoch: 40  Cumulative reward: -240.000000  Success rate: 0.0000 Mean loss: 0.1087
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_random.epochs_500.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
#@title Compare
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(15,'None',500)),
             os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(15,'final',500)),
             os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(15,'future',500)),
             os.path.join(SYM_PATH,logdir,'log_goal_conditioned.n_bits_{}.HER_{}.epochs_{}.csv'.format(15,'random',500))]

legends = ['15bits_HER_None_500epochs_avg',
           '15bits_HER_final_500epochs_avg',
           '15bits_HER_future_500epochs_avg',
           '15bits_HER_random_500epochs_avg']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, 'compare_goal_conditioned.HER.n_bits_{}.epochs_{}.png'.format(15,500))

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_None.epochs_500.csv
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_final.epochs_500.csv
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_future.epochs_500.csv
# /content/cs330_hw3/logs/log_goal_conditioned.n_bits_15.HER_random.epochs_500.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:54: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %% [markdown]
# # Sawyer Environment Goal-Conditioned RL

# %%
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
import multiworld
import glfw

multiworld.register_all_envs()   

class Model(tf.keras.Model):

  def __init__(self, num_act):
    super(Model, self).__init__()

    hidden_dim = 256
    self.dense1 = tf.keras.layers.Dense(hidden_dim, activation=tf.nn.relu)
    self.out = tf.keras.layers.Dense(num_act,activation = None)

  def call(self, inputs):
    x = self.dense1(inputs)
    return self.out(x)
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# ************   Helper functions    ************ #
# Globals

NUM_DIM = 2
NUM_ACT = 4
done_threshold = -0.01
Sawyer_Env = env = wrap_env(gym.make('SawyerReachXYEnv-v1'))

def updateTarget(model, target_model, tau=0.95) :
    model_weights = model.get_weights()
    target_weights = target_model.get_weights()
    new_weights = []
    for i, weight in enumerate(model_weights):
      new_weights.append(tau * target_weights[i] + (1 - tau) * weight)

    target_model.set_weights(new_weights)

def take_action(action, render):
    '''passes the discrete action selected by the Q-network to the Sawyer Arm.
    The function returns the next state, the reward, and whether the environment
    was solved. The environment done returned is not the same as the environment
    done returned by the Sawyer environment. Due to discretization, it may not be
    possible to exactly reach the goal. The done flag returns true if the end
    state is within done_threshold of the final goal

    inputs:  action - integer (0 to NUM_ACT-1) selected by the Q-network
    outputs: next_state - new state (x, y) location of arm
             reward - reward returned by Sawyer environment
             done - boolean whether environment is solved'''

    # maps actions selected by Q-network to Sawyer arm actions
    # array MUST be length NUM_ACT
    action_dic = {0:[-1, 0], 1:[1, 0], 2:[0, -1], 3:[0, 1]}
    # look up which action in Sawyer arm space corresponds to the selected integer action
    action_sawyer = np.array(action_dic[action], dtype=np.float32)
    # take the action
    ob, reward, done, info = Sawyer_Env.step(action_sawyer)
    # if rendering is turned on, render the environment
    if render:
        Sawyer_Env.render(mode='rgb_array')
    # check if we're "close enough" to declare done
    if reward > done_threshold:
        done = True

    # pull the observed state off
    next_state = ob['observation'][0:2]

    return next_state, reward, done, info

def solve_environment(model, state, goal_state, total_reward, steps_per_episode, render):
    '''attempt to solve the Sawyer Arm environment using the current policy'''
    
    # list for recording what happened in the episode
    episode_experience = []
    succeeded = False

    for t in range(steps_per_episode):
        inputs = np.concatenate((state, goal_state))
        inputs = np.expand_dims(inputs, axis=0)
        inputs = np.array(inputs, dtype=np.float32) 
        # forward pass to find action
        out = model(inputs)
        action = np.argmax(out,axis = 1)[0]
        next_state,reward,done, _ = take_action(action, render)
        # add to the episode experience (what happened)
        episode_experience.append((state,action,reward,next_state,goal_state))
        # calculate total reward
        total_reward += reward
        # update state
        state = next_state
        # mark that we've finished the episode and succeeded with training
        if done:
            if succeeded:
                continue
            else:
                succeeded = True
    else:
         env.stats_recorder.save_complete()
         env.stats_recorder.done = True
         
    return succeeded, episode_experience, total_reward


def solve_environment_no_goal(model, state, goal_state, total_reward, steps_per_episode, render):
    '''attempt to solve the Sawyer Arm environment using the current policy with no goal condition'''
    
    # list for recording what happened in the episode
    episode_experience = []
    succeeded = False

    for t in range(steps_per_episode):
        inputs = state
        inputs = np.expand_dims(inputs, axis=0)
        inputs = np.array(inputs, dtype=np.float32) 
        # forward pass to find action
        out = model(inputs)
        action = np.argmax(out,axis = 1)[0]
        next_state,reward,done, _ = take_action(action, render)
        # add to the episode experience (what happened)
        episode_experience.append((state,action,reward,next_state,goal_state))
        # calculate total reward
        total_reward += reward
        # update state
        state = next_state
        # mark that we've finished the episode and succeeded with training
        if done:
            if succeeded:
                continue
            else:
                succeeded = True
    else:
         env.stats_recorder.save_complete()
         env.stats_recorder.done = True

    return succeeded, episode_experience, total_reward

def update_replay_buffer(steps_per_episode, num_relabeled, replay_buffer, episode_experience, HER):
    '''adds past experience to the replay buffer. Training is done with episodes from the replay
    buffer. When HER is used, num_relabeled additional relabeled data points are also added
    to the replay buffer

    inputs:    epsidode_experience - list of transitions from the last episode
    modifies:  replay_buffer
    outputs:   None'''

    for t in range(steps_per_episode) :
        # copy actual experience from episode_experience to replay_buffer
        s,a,r,s_,g = episode_experience[t]
        # state
        inputs = s,
        # next state
        inputs_ = s_
        # add actual experience to the replay buffer
        replay_buffer.add(inputs,a,r,inputs_,g)

        # when HER is used, each call to update_replay_buffer should add num_relabeled
        # relabeled points to the replay buffer

        if HER == 'None':
            # If HER not being used, then use the actual goal state
            pass

        elif HER == 'final':
            # final - relabel based on final state in episode
            # pretend that final state in this episode is the goal and add to buffer
            _,_,_,s_goal_,_ = episode_experience[-1]

            # compute reward for this new goal state
            # In Sawyer environment reward is given by negative euclidean 
            # distance between goal state and the next state reached
            rewards = -np.linalg.norm(inputs_-s_goal_)
            replay_buffer.add(inputs,a,rewards,inputs_,s_goal_)

        elif HER == 'future':
            # future - relabel based on future state. At each timestep t, relabel the
            # goal with a randomly select timestep between t and the end of the
            # episode
            for t_ in range(num_relabeled):
              # relabel this experience with a randomly chosen future experience as goal
              goal_idx = np.random.randint(t, steps_per_episode, 1)
              # get goal state randomly from a future experience in current episode
              _,_,_,s_goal_,_ = episode_experience[goal_idx[0]]

              # compute reward for this new goal state
              # In Sawyer environment reward is given by negative euclidean 
              # distance between goal state and the next state reached
              rewards = -np.linalg.norm(inputs_-s_goal_)
              replay_buffer.add(inputs,a,rewards,inputs_,s_goal_)

        elif HER == 'random':
            # random - relabel based on a random state in the episode
            for t_ in range(num_relabeled):
              # relabel this experience with a randomly chosen future experience as goal
              goal_idx = np.random.randint(0, steps_per_episode, 1)
              # get goal state randomly from a future experience in current episode
              _,_,_,s_goal_,_ = episode_experience[goal_idx[0]]

              # compute reward for this new goal state
              # In Sawyer environment reward is given by negative euclidean 
              # distance between goal state and the next state reached
              rewards = -np.linalg.norm(inputs_ - s_goal_)
              replay_buffer.add(inputs,a,rewards,inputs_,s_goal_)

        else:
            print("Invalid value for Her flag - HER not used")
    return

# %%
import csv
# ************   Main Training Loop    ************ #

def run_sawyer(num_epochs, buffer_size = 1e6, batch_size = 128, 
               num_episodes = 16, num_relabeled = 4, gamma = 0.98, log_interval=5, opt_steps=40,
               steps_per_episode=50, render=False, HER = "None", logdir='logs', logfile='log.csv'):
    '''Main loop for running in the Sawyer environment. The DQN is
    trained over num_epochs. In each epoch, the agent runs in the environment
    num_episodes number of times. The Q-target and Q-policy networks are
    updated at the end of each epoch. Within one episode, Q-policy attempts
    to solve the environment and is limited to the same number as steps as the
    size of the environment

    inputs: HER - string specifying whether to use HER'''

    # csv writer to log accuracies
    print('Logging to -> {}'.format(os.path.join(SYM_PATH,logdir,logfile)))
    if not os.path.exists(os.path.join(SYM_PATH,logdir)):
      os.system('mkdir -p {}'.format(os.path.join(SYM_PATH,logdir)))

    with open(os.path.join(SYM_PATH,logdir,logfile), 'w', newline='') as csvfile:
      fieldnames = ['epoch',            \
                    'cumulative_reward',\
                    'success_rate',     \
                    'mean_loss'         ]
      # write header
      csv_writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
      csv_writer.writeheader()

      # create Sawyer arm environment and replay buffer
      replay_buffer = Buffer(buffer_size,batch_size)

      # set up Q-policy (model) and Q-target (target_model)
      model = Model(NUM_ACT)
      target_model = Model(NUM_ACT)

      optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3)

      # modify to be goal conditioned
      reset_state = Sawyer_Env.reset()  
      state = reset_state['observation'][:2]          # look up the state
      goal_state = reset_state['desired_goal'][:2]    # look up the goal
      
      inputs = np.concatenate((state, goal_state))
      inputs = np.expand_dims(inputs, axis=0)  
      model(inputs)
      target_model(inputs)

      # start by making Q-target and Q-policy the same
      updateTarget(model, target_model, tau=0.0)

      total_loss = []                  # training loss for each epoch
      success_rate = []                # success rate for each epoch
      
      for i in range(num_epochs):
          # Run for a fixed number of epochs

          total_reward = 0.0           # total reward for the epoch
          successes = []               # record success rate for each episode of the epoch
          losses = []                  # loss at the end of each epoch

          for k in range(num_episodes):
              reset_state = Sawyer_Env.reset()                # reset the environment
              state = reset_state['observation'][:2]          # look up the state
              goal_state = reset_state['desired_goal'][:2]    # look up the goal

              # attempt to solve the environment
              # modify to be goal conditioned
              succeeded, episode_experience, total_reward = solve_environment(model, state, goal_state, total_reward, steps_per_episode, render)

              successes.append(succeeded)                     # track whether we succeeded in environment 
              update_replay_buffer(steps_per_episode, num_relabeled, replay_buffer, episode_experience, HER)   # add to the replay buffer; use specified  HER policy
              env.close() 
              glfw.terminate()

          for k in range(opt_steps):
              # optimize the Q-policy network

              # sample from the replay buffer
              state,action,reward,next_state,goal_state = replay_buffer.sample()
              state = np.array(state, dtype=np.float32) 
              next_state = np.array(next_state, dtype=np.float32) 
              # modify the inputs to make them goal conditioned
              inputs = np.concatenate((state, goal_state), axis=-1) # goal conditioned
              inputs_ = np.concatenate((next_state, goal_state), axis=-1) # goal conditioned
              # forward pass through target network   

              with tf.GradientTape() as tape:
                target_net_Q = target_model(inputs_)
                # calculate target reward
                target_reward = np.clip(np.reshape(reward,[-1]) + gamma * np.reshape(np.max(target_net_Q,axis = -1),[-1]),-1. / (1 - gamma), 0)
                # calculate loss
                model_predict = model(inputs)
                model_action_taken = np.reshape(action,[-1])
                action_one_hot = tf.one_hot(model_action_taken, NUM_ACT)
                Q_val = tf.reduce_sum(model_predict * action_one_hot, axis=1)
                loss = tf.reduce_mean(tf.square(Q_val - target_reward))
                losses.append(loss)
              
              gradients = tape.gradient(loss, model.trainable_variables)
              optimizer.apply_gradients(zip(gradients, model.trainable_variables))
              
          updateTarget(model, target_model)               # update target model by copying Q-policy to Q-target      
          success_rate.append(np.mean(successes))       # append mean success rate for this epoch

          # write to csv file
          csv_writer.writerow({'epoch'              : i,                    
                               'cumulative_reward'  : total_reward,       
                               'success_rate'       : np.mean(successes), 
                               'mean_loss'          : np.mean(losses)     })

          if i % log_interval == 0:
              print('Epoch: %d  Cumulative reward: %f  Success rate: %.4f Mean loss: %.4f' % (i, total_reward, np.mean(successes), np.mean(losses)))
    return success_rate

# %%
her_type = 'None'
n_epochs = 150
exp_name = 'log_sawyer.HER_{}.epochs_{}'.format(her_type, n_epochs)
logdir = 'logs'
success_rate = run_sawyer(num_epochs=n_epochs, HER=her_type, render=False, logdir=logdir, logfile=exp_name+'.csv')
# Out:
# Logging to -> /content/cs330_hw3/logs/log_sawyer.HER_None.epochs_150.csv
# WARNING:tensorflow:Layer model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_sawyer.HER_None.epochs_150.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
her_type = 'final'
n_epochs = 150
exp_name = 'log_sawyer.HER_{}.epochs_{}'.format(her_type, n_epochs)
logdir = 'logs'
success_rate = run_sawyer(num_epochs=n_epochs, HER=her_type, render=False, logdir=logdir, logfile=exp_name+'.csv')
# Out:
# Logging to -> /content/cs330_hw3/logs/log_sawyer.HER_final.epochs_150.csv
# WARNING:tensorflow:Layer model_18 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# ...

# %%
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,exp_name+'.csv')]

legends = ['raw_values',
           'running_avarage']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, exp_name+'.png')

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_sawyer.HER_final.epochs_150.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:61: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
#@title Compare
# Plot the results
# compare training with and without learnable learning rate
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import deque

# compute moving average
def moving_average(x, n):
    # create a deque object
    x_deque = deque(maxlen=n)
    ma_x = []
    for x_ in x:
        x_deque.append(x_)
        ma_x.append(np.mean(x_deque))
    return np.array(ma_x)

# Plot the graphs
csv_files = [os.path.join(SYM_PATH,logdir,'log_sawyer.HER_{}.epochs_{}.csv'.format('None',150)),
             os.path.join(SYM_PATH,logdir,'log_sawyer.HER_{}.epochs_{}.csv'.format('final',150))]

legends = ['sawyer_HER_None_150epochs_raw',
           'sawyer_HER_None_150epochs_avg',
           'sawyer_HER_final_150epochs_raw',
           'sawyer_HER_final_150epochs_avg']

# plot filename
plotdir = 'plots'
os.system('mkdir -p {}'.format(os.path.join(SYM_PATH, plotdir)))
plot_fname = os.path.join(SYM_PATH, plotdir, 'compare_sawyer.HER_{}_{}.epochs_{}_{}.png'.format('None','final',150,150))

# plot graph
plt.figure(figsize=(16,16))

for i in range(len(csv_files)):
    epochs, cumulative_reward, success_rate, mean_loss = [], [], [], []
    print(csv_files[i])
    with open(csv_files[i]) as file:
        reader = csv.DictReader( file )
        for line in reader:
            epochs.append(int(line['epoch']))
            cumulative_reward.append(float(line['cumulative_reward']))
            success_rate.append(float(line['success_rate']))
            mean_loss.append(float(line['mean_loss']))
    
        # compute moving average
        cumulative_reward_avg = moving_average(cumulative_reward, 20)
        success_rate_avg = moving_average(success_rate, 20)
        mean_loss_avg = moving_average(mean_loss, 20)
        
    # plot graphs    
    plt.subplot(3,1,1)
    plt.plot(epochs, cumulative_reward, alpha=0.3)
    plt.plot(epochs, cumulative_reward_avg)
    
    plt.subplot(3,1,2)
    plt.plot(epochs, success_rate, alpha=0.3)
    plt.plot(epochs, success_rate_avg)

    plt.subplot(3,1,3)
    plt.plot(epochs, mean_loss, alpha=0.3)
    plt.plot(epochs, mean_loss_avg)

# info
plt.subplot(3,1,1)
plt.legend(legends)
plt.title('Cumulative Reward')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,2)
plt.legend(legends)
# plt.ylim(0.0, 1.0)
plt.title('Success Rate')
plt.grid()
plt.xlabel('epochs')

plt.subplot(3,1,3)
plt.legend(legends)
plt.title('Mean Loss')
plt.grid()
plt.xlabel('epochs')

# save plot to file
plt.savefig(plot_fname)
plt.show()
# Out:
# /content/cs330_hw3/logs/log_sawyer.HER_None.epochs_150.csv
# /content/cs330_hw3/logs/log_sawyer.HER_final.epochs_150.csv
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:52: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:56: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
# If you chose to render:
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
